# %%
import pandas as pd
import os
import csv
import numpy as np

import warnings
warnings.filterwarnings("ignore")

class Nstr:
    def __init__(self,arg):
        self.x=arg
    def __sub__(self,other):
        c=self.x.replace(other.x,"")
        return c
path = "C:/Users/Xia HAN/Downloads/jupyter_code_data_WEI_kunni/code_20221124/ShanE_green_sumband_longeur_vector" ##ShanE_black_sumband_exeTime
filename = os.listdir(path)
#filename= os.listdir(r'C:\\Users\Xia HAN\\Downloads\\jupyter_code_data_WEI_kunni\\code_20221124\\ShanE_black_sumband_longeur_vector')##longeur_vector

#print(filename)  ## 路径下所有文件名
#for i in range(0,1):   ##############该行为测试用
for i in range(len(filename)):   
    #print(filename[i])
    #print("")
    rforest=[]
    sVMachine=[]
    lRegression=[]
    kNN=[]
    dTree=[]
    cBoost=[]
    
    mean_rforest=[]
    mean_sVMachine=[]
    mean_lRegression=[]
    mean_kNN=[]
    mean_dTree=[]
    mean_cBoost=[]
    
    data_xlsx=[]
    
    with open(filename[i], 'r',encoding="utf-8",newline='') as file:
        data = csv.reader(file)
        #print(data)
        #data_list = list(data)  ##读取整个csv列表,data_list[0]表示第一行，以此类推
        #print(data_list)
        next(data)
        #print(data)
    #for file in filename:
        #data_xls = pd.read_excel('1.xlsx',index_col=0)
        #data_xls.to_csv('1.csv',encoding='utf-8')
        
        #data_xlsx= pd.read_excel(path+"/"+file)
        
        #print(data_xlsx)
        for r in data:
        #for r in data_xlsx:
            #print(r)
            #print(rforest)
            rforest.append(float(r[1]))  ### r[1]表示该行的第2列
            #print(rforest)
            sVMachine.append(float(r[2]))
            lRegression.append(float(r[3]))
            kNN.append(float(r[4]))
            dTree.append(float(r[5]))
            cBoost.append(float(r[6]))
            
            mean_rforest = np.mean(rforest)
            mean_sVMachine = np.mean(sVMachine)
            mean_lRegression = np.mean(lRegression)
            mean_kNN = np.mean(kNN)
            mean_dTree = np.mean(dTree)
            mean_cBoost = np.mean(cBoost)
        ##文件名 ShanE_black_sumband_30_9_Fp1_1_vectorLongeur
        ######## ShanE_black_sumband_30_9_Fp1_1_exeTime
        ########ShanE_black_Fp1z2_30_3_9_1_vectorLongeur.csv
        prefix_fileName = Nstr("ShanE_green_5band_")
        suffix_fileName1 = Nstr("vectorLongeur")
        suffix_fileName2 = Nstr(".csv") 
        new_fileName = Nstr(filename[i]) - prefix_fileName
        new_fileName=Nstr(new_fileName)- suffix_fileName1  ##
        new_fileName=Nstr(new_fileName)- suffix_fileName2
        new_fileName = new_fileName+"acc"
        #
        Avg=[new_fileName,mean_rforest,mean_sVMachine,mean_lRegression,mean_kNN,mean_dTree,mean_cBoost]
        print(Avg)
# Out:
# ['30_9_Fp1_1_acc', 0.6022222222222221, 0.47444444444444445, 0.41111111111111115, 0.4677777777777778, 0.6022222222222221, 0.581111111111111]
# ['30_9_Fp1_2_acc', 0.5555555555555556, 0.6455555555555555, 0.47666666666666674, 0.5344444444444444, 0.52, 0.5777777777777777]
# ['30_9_Fp1_3_acc', 0.6855555555555556, 0.7311111111111112, 0.4855555555555556, 0.5744444444444444, 0.6655555555555557, 0.6944444444444445]
# ['30_9_Fp1_4_acc', 0.6522222222222221, 0.6977777777777776, 0.4444444444444446, 0.6355555555555555, 0.5877777777777777, 0.6533333333333333]
# ['30_9_Fp1_5_acc', 0.6511111111111112, 0.6633333333333336, 0.42666666666666664, 0.5866666666666667, 0.5988888888888889, 0.6422222222222221]
# ['30_9_Fp1_6_acc', 0.6288888888888889, 0.6255555555555555, 0.39000000000000007, 0.5066666666666666, 0.5744444444444443, 0.6266666666666666]
# ['30_9_Fp1_7_acc', 0.672222222222222, 0.6222222222222221, 0.3555555555555556, 0.5455555555555556, 0.6300000000000001, 0.6533333333333333]
# ['30_9_Fp1_8_acc', 0.6244444444444445, 0.5844444444444445, 0.34777777777777785, 0.5422222222222222, 0.6133333333333334, 0.6322222222222221]
# ['30_9_Fp1_9_acc', 0.62, 0.6188888888888888, 0.35111111111111115, 0.5155555555555555, 0.6366666666666666, 0.6388888888888888]
# ['30_9_Fp2_1_acc', 0.4522222222222223, 0.4777777777777778, 0.39111111111111113, 0.43000000000000005, 0.4522222222222223, 0.46111111111111114]
# ['30_9_Fp2_2_acc', 0.43999999999999995, 0.4700000000000001, 0.40111111111111114, 0.43666666666666665, 0.47888888888888886, 0.4422222222222223]
# ['30_9_Fp2_3_acc', 0.40444444444444455, 0.47888888888888886, 0.3455555555555555, 0.4522222222222222, 0.3977777777777778, 0.3922222222222222]
# ['30_9_Fp2_4_acc', 0.48111111111111104, 0.5322222222222223, 0.3944444444444445, 0.5522222222222222, 0.4644444444444445, 0.4955555555555555]
# ['30_9_Fp2_5_acc', 0.53, 0.5733333333333333, 0.45333333333333337, 0.5966666666666667, 0.5155555555555555, 0.5177777777777779]
# ['30_9_Fp2_6_acc', 0.5244444444444444, 0.5711111111111111, 0.41222222222222216, 0.5222222222222221, 0.49, 0.5133333333333333]
# ['30_9_Fp2_7_acc', 0.5211111111111112, 0.5566666666666666, 0.44444444444444436, 0.5311111111111111, 0.5488888888888888, 0.5111111111111112]
# ['30_9_Fp2_8_acc', 0.48444444444444434, 0.5644444444444445, 0.3988888888888889, 0.5511111111111111, 0.51, 0.5033333333333333]
# ['30_9_Fp2_9_acc', 0.4822222222222222, 0.5566666666666665, 0.4155555555555556, 0.55, 0.48666666666666664, 0.5177777777777777]
# ['30_9_Fpz_1_acc', 0.5444444444444444, 0.5511111111111111, 0.43, 0.5199999999999999, 0.5444444444444444, 0.5288888888888889]
# ['30_9_Fpz_2_acc', 0.5777777777777778, 0.5422222222222222, 0.4355555555555555, 0.5333333333333333, 0.6, 0.5722222222222222]
# ['30_9_Fpz_3_acc', 0.6099999999999999, 0.5377777777777777, 0.4255555555555556, 0.4322222222222223, 0.5911111111111111, 0.5966666666666667]
# ['30_9_Fpz_4_acc', 0.5577777777777777, 0.6077777777777778, 0.4122222222222222, 0.52, 0.5244444444444444, 0.5677777777777777]
# ['30_9_Fpz_5_acc', 0.6211111111111112, 0.6488888888888888, 0.3777777777777777, 0.5955555555555556, 0.5355555555555556, 0.6344444444444445]
# ['30_9_Fpz_6_acc', 0.5933333333333334, 0.678888888888889, 0.3333333333333334, 0.5877777777777777, 0.5433333333333333, 0.6222222222222222]
# ['30_9_Fpz_7_acc', 0.6244444444444445, 0.6733333333333333, 0.5422222222222222, 0.5966666666666667, 0.55, 0.6377777777777778]
# ['30_9_Fpz_8_acc', 0.6233333333333333, 0.7044444444444443, 0.46888888888888886, 0.59, 0.5355555555555556, 0.6455555555555555]
# ['30_9_Fpz_9_acc', 0.6188888888888888, 0.691111111111111, 0.44666666666666655, 0.5988888888888888, 0.5522222222222222, 0.65]
